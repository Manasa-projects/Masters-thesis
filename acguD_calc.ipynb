# %%
file2 = open(r"lnc11acguD.txt", "r")
file_lines = file2.read()



s1 = file_lines.split("\n")

# %%
file2 = open(r"lnc12acguD.txt", "r")
file_lines = file2.read()



s2 = file_lines.split("\n")

# %%
file2 = open(r"lnc13acguD.txt", "r")
file_lines = file2.read()



s3 = file_lines.split("\n")

# %%
file2 = open(r"lnc14acguD.txt", "r")
file_lines = file2.read()



s4 = file_lines.split("\n")

# %%
file2 = open(r"lnc15acguD.txt", "r")
file_lines = file2.read()



s5= file_lines.split("\n")

# %%
file2 = open(r"lnc16acguD.txt", "r")
file_lines = file2.read()



s6 = file_lines.split("\n")

# %%
file2 = open(r"lnc17acguD.txt", "r")
file_lines = file2.read()



s7 = file_lines.split("\n")

# %%
file2 = open(r"lnc18acguD.txt", "r")
file_lines = file2.read()



s8 = file_lines.split("\n")

# %%
sfull=s1+s2+s3+s4+s5+s6+s7+s8

# %%
sactual=[]
for i in range(0,len(sfull)):
    if sfull[i]!='':
        sactual.append(sfull[i])

# %%
file2 = open(r"lncreftotalacguD.txt", "r")
file_lines = file2.read()



lncref = file_lines.split("\n")

# %%
lncref2=[]
for i in range(0,len(lncref)):
    if lncref[i]!='':
        lncref2.append(lncref[i])

# %%
import ast
lncref1=[]
for i in range(0,len(lncref2)):
    u = ast.literal_eval(lncref2[i])
    lncref1.append(u)

# %%
file2 = open(r"pctreftotalacguD.txt", "r")
file_lines = file2.read()


pctref = file_lines.split("\n")

# %%
pctref2=[]
for i in range(0,len(pctref)):
    if pctref[i]!='':
        pctref2.append(pctref[i])

# %%
pctref1=[]
for i in range(0,len(pctref2)):
    u = ast.literal_eval(pctref2[i])
    pctref1.append(u)

# %%
file2 = open(r"pct11acguD.txt", "r")
file_lines = file2.read()



p1 = file_lines.split("\n")

# %%
file2 = open(r"pct12acguD.txt", "r")
file_lines = file2.read()



p2 = file_lines.split("\n")

# %%
file2 = open(r"pct13acguD.txt", "r")
file_lines = file2.read()



p3 = file_lines.split("\n")

# %%
file2 = open(r"pct14acguD.txt", "r")
file_lines = file2.read()



p4 = file_lines.split("\n")

# %%
file2 = open(r"pct15acguD.txt", "r")
file_lines = file2.read()



p5 = file_lines.split("\n")

# %%
file2 = open(r"pct16acguD.txt", "r")
file_lines = file2.read()



p6 = file_lines.split("\n")

# %%
file2 = open(r"pct17acguD.txt", "r")
file_lines = file2.read()



p7 = file_lines.split("\n")

# %%
file2 = open(r"pct18acguD.txt", "r")
file_lines = file2.read()



p8 = file_lines.split("\n")

# %%
ptotal=p1+p2+p3+p4+p5+p6+p7+p8

# %%
pactual=[]
for i in range(0,len(ptotal)):
    if ptotal[i]!='':
        pactual.append(ptotal[i])

# %%
tots=sactual+pactual

# %%
import numpy as np
lfinal=[]
pfinal=[]
for i in range(0,len(tots)):
    t=ast.literal_eval(tots[i])
    
    for j in range(0,len(t)):
        if t[j][1]!=0:
            try:
                r=t[j][1]/lncref1[j][1]
                rdash=np.log(r)
            except:
                rdash=None
        else:
            rdash=0
        lncvalue1.append(rdash)
        if t[j][1]!=0:
    
            try:
                q=t[j][1]/pctref1[j][1]
                qdash=np.log(q)
            except:
                qdash=None
        else:
            qdash=0
        pctvalue1.append(qdash)
        lprimary=[]
        for k in range(0,len(lncvalue1)):
            a=0
            b=0
            c=0
            d=0
            if lncvalue1[k]==0:
                a=a+1
            
            elif lncvalue1[k]==None:
                b=b+1
            else:
                c=c+lncvalue1[k]
            if lncvalue1[k]!=None:
                d=d+lncvalue1[k]
        l=(c-a+b)/d
        lprimary.append(l)
        pprimary=[]
        for k in range(0,len(pctvalue1)):
            a=0
            b=0
            c=0
            d=0
            if pctvalue1[k]==0:
                a=a+1
            
            elif pctvalue1[k]==None:
                b=b+1
            else:
                c=c+pctvalue1[k]
            if pctvalue1[k]!=None:
                d=d+pctvalue1[k]
        l=(c-a+b)/d
        pprimary.append(l)
    lfinal.append(lprimary)
    pfinal.append(pprimary)

# %%
file3 = open(r"pacguD1.txt", "r")
file_lines1 = file3.read()



pdash1 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD2.txt", "r")
file_lines1 = file3.read()



pdash2 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD3.txt", "r")
file_lines1 = file3.read()



pdash3 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD4.txt", "r")
file_lines1 = file3.read()



pdash4 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD5.txt", "r")
file_lines1 = file3.read()



pdash5 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD6.txt", "r")
file_lines1 = file3.read()



pdash6 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD7.txt", "r")
file_lines1 = file3.read()



pdash7 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD8.txt", "r")
file_lines1 = file3.read()



pdash8 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD9.txt", "r")
file_lines1 = file3.read()



pdash9 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD10.txt", "r")
file_lines1 = file3.read()



pdash10 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD11.txt", "r")
file_lines1 = file3.read()



pdash11 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD12.txt", "r")
file_lines1 = file3.read()



pdash12 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD13.txt", "r")
file_lines1 = file3.read()



pdash13 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD14.txt", "r")
file_lines1 = file3.read()



pdash14 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD15.txt", "r")
file_lines1 = file3.read()



pdash15 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD16.txt", "r")
file_lines1 = file3.read()



pdash16 = file_lines1.split("\n")

# %%
file3 = open(r"pacguD17.txt", "r")
file_lines1 = file3.read()



pdash17 = file_lines1.split("\n")

# %%
pc=pdash1+pdash2+pdash3+pdash4+pdash5+pdash6+pdash7+pdash8+pdash9+pdash10+pdash11+pdash12+pdash13+pdash14+pdash15+pdash16+pdash17

# %%
pc2=[]
for i in range(0,len(pc)):
    if pc[i]!='':
        pc2.append(pc[i])

# %%
len(pc2)
# Out:
# 8144

# %%
import ast
pc3=[]
for i in range(0,len(pc2)):
    u = ast.literal_eval(pc2[i])
    pc3.append(u)

# %%
pc5=[]
for i in range(0,len(pc3)):
    pc5=pc5+pc3[i]

# %%
pc4=[]
for i in range(0,len(pc5)):
    d=pc5[i]/15625
    pc4.append(d)

# %%
import csv
with open('pacguDcalc.csv', 'w') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
      
    write.writerow(pc4)

# %%
import random
randnum=random.randrange(-0.6,0.6,8138)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-7050009f0062> in <module>
#       1 import random
# ----> 2 randnum=random.randrange(-0.6,0.6,8138)
#
# ~\Anaconda3\lib\random.py in randrange(self, start, stop, step, _int)
#     184         istart = _int(start)
#     185         if istart != start:
# --> 186             raise ValueError("non-integer arg 1 for randrange()")
#     187         if stop is None:
#     188             if istart > 0:
#
# ValueError: non-integer arg 1 for randrange()

# %%
import random
randnum=[random.random() for randnum in range(8138) ]

# %%
randnum
# Out:
# [0.5227219902918311,
#  0.8203332874389915,
#  0.980361646082596,
#  0.08470169468887578,
#  0.7912031411296301,
#  0.12051990726344508,
#  0.5307325917223735,
#  0.23040963438636686,
#  0.3073405860008789,
#  0.60009757979246,
#  0.6706831684661413,
#  0.2580141454389916,
#  0.11905819050894972,
#  0.34442106333201694,
#  0.516375079990656,
#  0.8395087867809263,
#  0.7654396904795641,
#  0.06281313734331972,
#  0.35591733047515084,
#  0.9250579284992672,
#  0.7527178853130797,
#  0.8179492469912444,
#  0.45898909480846084,
#  0.159488691003715,
#  0.5667707884456291,
#  0.26382085352699125,
#  0.6271315726866213,
#  0.10439888284929844,
#  0.4611519626908769,
#  0.40070953347252836,
#  0.09243226930330328,
#  0.41098407039913976,
#  0.7858636437534783,
#  0.9049849108945214,
#  0.2865208091920387,
#  0.9260908597652581,
#  0.9412754224438269,
#  0.806342284855308,
#  0.47060595109943804,
#  0.8560305836172165,
#  0.5790704069649479,
#  0.8656307920974535,
#  0.34761596098061476,
# ...
